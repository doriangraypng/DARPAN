# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("1_to142.csv")
df = pd.read_csv("COMPLETED_PROJECT_JAN2026.csv")
df = pd.read_csv("MAJOR_ONGOING_PROJECT_JAN2026.csv")
df = pd.read_csv("sector_jan26.csv")
